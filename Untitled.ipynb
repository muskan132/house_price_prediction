# %%
import pandas as pd

# %%
hd=pd.read_csv("train.csv")

# %%
hd.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hd.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
hd.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
hd.isnull().sum()>0
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage       True
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType         False
# SaleCondition    False
# SalePrice        False
# Length: 81, dtype: bool

# %%
nd=hd.isnull().sum()

# %%
nd[hd.isnull().sum()>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
len(hd)
# Out:
# 1460

# %%
hd.drop(['Alley','PoolQC','MiscFeature'], inplace=True, axis=1)

# %%
hd
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea  \
# ...

# %%
pd.set_option("display.max_columns", None)
hd.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
hd['MiscVal'].sum()
# Out:
# 63494

# %%
hd.loc[hd['MiscVal']>0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 5        6          50       RL         85.0    14115   Pave      IR1
# 7        8          60       RL          NaN    10382   Pave      IR1
# 16      17          20       RL          NaN    11241   Pave      IR1
# 17      18          90       RL         72.0    10791   Pave      Reg
# 51      52          50       RM         52.0     6240   Pave      Reg
# 84      85          80       RL          NaN     8530   Pave      IR1
# 95      96          60       RL          NaN     9765   Pave      IR2
# 98      99          30       RL         85.0    10625   Pave      Reg
# 99     100          20       RL         77.0     9320   Pave      IR1
# 106    107          30       RM         60.0    10800   Pave      Reg
# 214    215          60       RL          NaN    10900   Pave      IR1
# 249    250          50       RL          NaN   159000   Pave      IR2
# ...

# %%
len(hd.loc[hd['MiscVal']>0])
# Out:
# 52

# %%
hd.drop(['PoolArea','MiscVal'], inplace=True, axis=1)

# %%
nd=hd.isnull().sum()
nd[hd.isnull().sum()>0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# Fence           1179
# dtype: int64

# %%
hd.Fence.fillna("No Fence")
# Out:
# 0       No Fence
# 1       No Fence
# 2       No Fence
# 3       No Fence
# 4       No Fence
#           ...
# 1455    No Fence
# 1456       MnPrv
# 1457       GdPrv
# 1458    No Fence
# 1459    No Fence
# Name: Fence, Length: 1460, dtype: object

# %%
hd.GarageFinish.fillna("No Garage")
# Out:
# 0       RFn
# 1       RFn
# 2       RFn
# 3       Unf
# 4       RFn
#        ...
# 1455    RFn
# 1456    Unf
# 1457    RFn
# 1458    Unf
# 1459    Fin
# Name: GarageFinish, Length: 1460, dtype: object

# %%
cols=['GarageType','GarageYrBlt','GarageQual','GarageCond' ]
hd[cols]=hd[cols].fillna("No Garage")

# %%
hd[cols]
# Out:
#      GarageType GarageYrBlt GarageQual GarageCond
# 0        Attchd      2003.0         TA         TA
# 1        Attchd      1976.0         TA         TA
# 2        Attchd      2001.0         TA         TA
# 3        Detchd      1998.0         TA         TA
# 4        Attchd      2000.0         TA         TA
# ...         ...         ...        ...        ...
# 1455     Attchd      1999.0         TA         TA
# 1456     Attchd      1978.0         TA         TA
# 1457     Attchd      1941.0         TA         TA
# 1458     Attchd      1950.0         TA         TA
# 1459     Attchd      1965.0         TA         TA
#
# [1460 rows x 4 columns]

# %%
nd=hd[cols].isnull().sum()

# %%
nd[hd[cols].isnull().sum()>0]
# Out:
# Series([], dtype: int64)
